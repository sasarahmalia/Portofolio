# %%
import pandas

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
data = pandas.read_csv('/content/drive/MyDrive/TUBES/package_tourism.csv')
data.drop(["Package","Place_Tourism4", "Place_Tourism5"], axis = 1, inplace=True)
data
# Out:
#         City                   Place_Tourism1            Place_Tourism2  \
# 0    Jakarta                Pasar Tanah Abang              Taman Ayodya
# 1    Jakarta                Pasar Tanah Abang        Pasar Taman Puring
# 2    Jakarta            Perpustakaan Nasional                     Monas
# 3    Jakarta                     Pulau Tidung            Pulau Bidadari
# 4    Jakarta            Museum Satria Mandala             Museum Wayang
# ..       ...                              ...                       ...
# 95  Surabaya      Ekowisata Mangrove Wonorejo     Taman Harmoni Keputih
# 96  Surabaya                Ciputra Waterpark             Kenjeran Park
# 97  Surabaya    Museum Kesehatan Dr. Adhyatma  Patung Buddha Empat Rupa
# 98  Surabaya  Taman Ekspresi Dan Perpustakaan   Museum De Javasche Bank
# 99  Surabaya              Taman Buah Surabaya       Hutan Bambu Keputih
#
#                     Place_Tourism3
# 0                   Museum Tekstil
# ...

# %%
class Stack:
  def __init__(self, data):
    self.data = data
    self.kolom = []
    for i in self.data:
      self.kolom.append(i)
#melihat jumlah kolom dan baris
  def __len__(self):
    return f"{len(list(self.data[self.kolom[0]]))} rows × {len(self.kolom)} columns"
#mengecek data apakah data kosong
  def isempty(self):
    return len(list(self.data[self.kolom[0]])) == 0
#nampilin data
  def view(self):
    return self.data
#menambah data dari index terakhir ke data frame
#dataframe diubah ke list kemudian ditambah lalu diubah kembali ke dataframe
  def push(self, item):
    kol = {}
    j = 0
    for i in self.kolom:
      kol[j] = list(self.data[i])
      j += 1
    k = 0
    data = {}
    for j in item:
      kol[k].append(j)
      k += 1
    p = 0
    for m in self.kolom:
      data[m] = kol[p]
      p += 1
    self.data = pandas.DataFrame(data)
#menghapus dan menampilkan data trakhir
  def pop(self):
    if self.isempty():
      raise Exception('Stack kosong')
    else:
      data = {}
      df_a = self.data.tail(1)
      for i in self.kolom:
        data[i] = list(self.data[i])
        data[i].pop()
      self.data = pandas.DataFrame(data)
      return df_a
#menampilkan data paling terakhir
  def top(self):
    if self.isempty():
      raise Exception('Stack kosong')
    return self.data.tail(1)

# %%
wisata = Stack(data)
wisata.__len__()
wisata.isempty()
wisata.view()
wisata.push(["Lampung","Pantai Mutun " , "Gunung Sagi", "Puncak Mas"])
wisata.view()
# Out:
#          City                   Place_Tourism1            Place_Tourism2  \
# 0     Jakarta                Pasar Tanah Abang              Taman Ayodya
# 1     Jakarta                Pasar Tanah Abang        Pasar Taman Puring
# 2     Jakarta            Perpustakaan Nasional                     Monas
# 3     Jakarta                     Pulau Tidung            Pulau Bidadari
# 4     Jakarta            Museum Satria Mandala             Museum Wayang
# ..        ...                              ...                       ...
# 96   Surabaya                Ciputra Waterpark             Kenjeran Park
# 97   Surabaya    Museum Kesehatan Dr. Adhyatma  Patung Buddha Empat Rupa
# 98   Surabaya  Taman Ekspresi Dan Perpustakaan   Museum De Javasche Bank
# 99   Surabaya              Taman Buah Surabaya       Hutan Bambu Keputih
# 100   Lampung                    Pantai Mutun                Gunung Sagi
#
#                      Place_Tourism3
# 0                    Museum Tekstil
# ...

# %%
#data tearkhir dihapus kemudian ditampilkan
wisata.pop()
# Out:
#         City Place_Tourism1 Place_Tourism2 Place_Tourism3
# 100  Lampung  Pantai Mutun     Gunung Sagi     Puncak Mas

# %%
wisata.view()
# Out:
#         City                   Place_Tourism1            Place_Tourism2  \
# 0    Jakarta                Pasar Tanah Abang              Taman Ayodya
# 1    Jakarta                Pasar Tanah Abang        Pasar Taman Puring
# 2    Jakarta            Perpustakaan Nasional                     Monas
# 3    Jakarta                     Pulau Tidung            Pulau Bidadari
# 4    Jakarta            Museum Satria Mandala             Museum Wayang
# ..       ...                              ...                       ...
# 95  Surabaya      Ekowisata Mangrove Wonorejo     Taman Harmoni Keputih
# 96  Surabaya                Ciputra Waterpark             Kenjeran Park
# 97  Surabaya    Museum Kesehatan Dr. Adhyatma  Patung Buddha Empat Rupa
# 98  Surabaya  Taman Ekspresi Dan Perpustakaan   Museum De Javasche Bank
# 99  Surabaya              Taman Buah Surabaya       Hutan Bambu Keputih
#
#                     Place_Tourism3
# 0                   Museum Tekstil
# ...

# %%
#nambah data
wisata.push(["Sumatera Utara", "Danau Toba", "Gunung Sibayak", "Pantai Cermin"])

# %%
wisata.view()
# Out:
#                City                   Place_Tourism1  \
# 0           Jakarta                Pasar Tanah Abang
# 1           Jakarta                Pasar Tanah Abang
# 2           Jakarta            Perpustakaan Nasional
# 3           Jakarta                     Pulau Tidung
# 4           Jakarta            Museum Satria Mandala
# ..              ...                              ...
# 96         Surabaya                Ciputra Waterpark
# 97         Surabaya    Museum Kesehatan Dr. Adhyatma
# 98         Surabaya  Taman Ekspresi Dan Perpustakaan
# 99         Surabaya              Taman Buah Surabaya
# 100  Sumatera Utara                       Danau Toba
#
#                Place_Tourism2                  Place_Tourism3
# 0                Taman Ayodya                  Museum Tekstil
# 1          Pasar Taman Puring            Pasar Petak Sembilan
# 2                       Monas                 Masjid Istiqlal
# 3              Pulau Bidadari                      Pulau Pari
# ...

# %%
#untuk melihat data pling atas/terakhir
wisata.top()
# Out:
#                City Place_Tourism1  Place_Tourism2 Place_Tourism3
# 100  Sumatera Utara     Danau Toba  Gunung Sibayak  Pantai Cermin

# %%
wisata.push(["Lampung","Pantai Mutun " , "Gunung Sagi", "Puncak Mas"])
wisata.top()
# Out:
#         City Place_Tourism1 Place_Tourism2 Place_Tourism3
# 101  Lampung  Pantai Mutun     Gunung Sagi     Puncak Mas

# %%
wisata.view()
# Out:
#                City                   Place_Tourism1  \
# 0           Jakarta                Pasar Tanah Abang
# 1           Jakarta                Pasar Tanah Abang
# 2           Jakarta            Perpustakaan Nasional
# 3           Jakarta                     Pulau Tidung
# 4           Jakarta            Museum Satria Mandala
# ..              ...                              ...
# 97         Surabaya    Museum Kesehatan Dr. Adhyatma
# 98         Surabaya  Taman Ekspresi Dan Perpustakaan
# 99         Surabaya              Taman Buah Surabaya
# 100  Sumatera Utara                       Danau Toba
# 101         Lampung                    Pantai Mutun
#
#                Place_Tourism2                  Place_Tourism3
# 0                Taman Ayodya                  Museum Tekstil
# 1          Pasar Taman Puring            Pasar Petak Sembilan
# 2                       Monas                 Masjid Istiqlal
# 3              Pulau Bidadari                      Pulau Pari
# ...

# %%
wisata.__len__()
# Out:
# '102 rows × 4 columns'
